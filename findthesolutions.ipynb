# %% [markdown]
# <a href="https://www.kaggle.com/code/cihatatmaca/findthesolutions?scriptVersionId=194806061" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Try & except & else & finally

# %%
import pandas as pd
df = pd.read_csv("/kaggle/input/advertising/advertising.csv")
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# # title
